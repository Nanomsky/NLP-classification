# %% [markdown]
# # NLP Classification Project
#
# ##### Building a spam filter with the kernel framework.
#
# Emails are either classed as undersired "spam" or "ham". This classification task is applies and uses variants of edit distance within a kernel framework. LibSVM algorithm is then applied to clasify the data as either "ham" or "spam". The <a href = "https://archive.ics.uci.edu/ml/datasets/SMS+Spam+Collection"> SMS Spam Collection Data Set</a> from UCI machine learning repository is used for the experiment.
#
# * Clean the data
# * Carry out data exploration
# * split, tokenize, remove punctuation
# * Extract features
# * Construct kernels
# * Run classification
# * Compare and analyse

# %%
#Import required files
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import re
import string
from libsvm.svmutil import *
from util_ker import *
from util_ker import EvaluateTest
from util_Text import *
import seaborn as sns
import time

# %matplotlib inline
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ## Explore the Data

# %%
#Load Data
data = pd.read_csv("/Users/osita/Documents/GitHub/NLP-classification/data/SMSSpamCollection", sep='\t', header=None,
                   names=['label','Text'])

# %%
data.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   Text
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though

# %%
print('The data is made up of {} examples '.format(data.shape[0]))
# Out:
# The data is made up of 5572 examples

# %%
#Check for null values
data.isnull().sum()
# Out:
# label    0
# Text     0
# dtype: int64

# %%
len_ham  = data[data['label']=='ham'].count()[0]
len_spam = data[data['label']=='spam'].count()[0]

print('{} examples classed as ham with {} examples classed as spam'.format(len_ham, len_spam))
# Out:
# 4825 examples classed as ham with 747 examples classed as spam

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1);data.label.value_counts().plot(kind='bar',color=['C3','C5']); plt.title('Class Labels (Ham/Spam)')
plt.subplot(1,2,2);data.label.value_counts().plot(kind='pie');plt.legend(['Ham','Spam'])
plt.show()

# %%
# View a few examples of the text
data['Text'].values[0:5]
# Out:
# array(['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#        'Ok lar... Joking wif u oni...',
#        "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#        'U dun say so early hor... U c already then say...',
#        "Nah I don't think he goes to usf, he lives around here though"],
#       dtype=object)

# %%
#Extract the length of each example
lenData = np.zeros((len(data),1))
for i in range(len(data)):
    lenData[i] = len(data.Text[i])

# %%
#Plot a histogram showing the distribution of the variable length
plt.hist(lenData);
plt.title('Distribution of variable length examples');

# %% [markdown]
# ### Uneven length strings
#
# We can easily select an appropriate multivariate analytical tool to tackle statistical pattern recognition problems. The data exists as real valued vectors of equal length. This however becomes a challenge when dealing with uneven length structural pattern recognition tasks. For example this spam detection  problem.
#
# Here we apply the edit distance kernel framework with support vector machines

# %% [markdown]
# ### Clean Data
#
#  - Remove punctuation
#  - Tokenize the strings
#  - Remove stop words

# %%
data['Text_cleaned'] = data['Text'].apply(lambda x: clean_text(x)) #Applies the function to each row
data.head(10)
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
# 5  spam
# 6   ham
# 7   ham
# 8  spam
# 9  spam
#
#                                                                                                   Text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
# 5  FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for ...
# 6                        Even my brother is not like to speak with me. They treat me like aids patent.
# 7  As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your call...
# 8  WINNER!! As a valued network customer you have been selected to receivea £900 prize reward! To c...
# 9  Had your mobile 11 months or more? U R entitled to Update to the latest colour mobiles with came...
#
#                                                                                           Text_cleaned
# 0  [Go, jurong, point, crazy, Available, bugis, n, great, world, la, e, buffet, Cine, got, amore, wat]
# 1                                                                       [Ok, lar, Joking, wif, u, oni]
# 2  [Free, entry, 2, wkly, comp, win, FA, Cup, final, tkts, 21st, May, 2005, Text, FA, 87121, receiv...
# 3                                                        [U, dun, say, early, hor, U, c, already, say]
# 4                                              [Nah, I, dont, think, goes, usf, lives, around, though]
# 5  [FreeMsg, Hey, darling, 3, weeks, word, back, Id, like, fun, still, Tb, ok, XxX, std, chgs, send...
# 6                                        [Even, brother, like, speak, They, treat, like, aids, patent]
# 7  [As, per, request, Melle, Melle, Oru, Minnaminunginte, Nurungu, Vettam, set, callertune, Callers...
# 8  [WINNER, As, valued, network, customer, selected, receivea, 900, prize, reward, To, claim, call,...
# 9  [Had, mobile, 11, months, U, R, entitled, Update, latest, colour, mobiles, camera, Free, Call, T...

# %% [markdown]
# ### Apply Stemming

# %%
# ['Porter','Lancaster']
Stemmer = 'Porter'

# %%
data['Text_stemmed'] = data['Text_cleaned'].apply(lambda x: stemming(x,Stemmer))
data.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   Text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                           Text_cleaned  \
# 0  [Go, jurong, point, crazy, Available, bugis, n, great, world, la, e, buffet, Cine, got, amore, wat]
# 1                                                                       [Ok, lar, Joking, wif, u, oni]
# 2  [Free, entry, 2, wkly, comp, win, FA, Cup, final, tkts, 21st, May, 2005, Text, FA, 87121, receiv...
# 3                                                        [U, dun, say, early, hor, U, c, already, say]
# 4                                              [Nah, I, dont, think, goes, usf, lives, around, though]
#
#                                                                                           Text_stemmed
# 0        [Go, jurong, point, crazi, avail, bugi, n, great, world, la, e, buffet, cine, got, amor, wat]
# 1                                                                         [Ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, FA, cup, final, tkt, 21st, may, 2005, text, FA, 87121, receiv,...
# 3                                                        [U, dun, say, earli, hor, U, c, alreadi, say]
# 4                                                [nah, I, dont, think, goe, usf, live, around, though]

# %% [markdown]
# ### Lemmatize the data

# %%
data['Text_lemmatized'] = data['Text_stemmed'].apply(lambda x: lemmatizing(x))

data.head()
# Out:
#   label  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                   Text  \
# 0  Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there g...
# 1                                                                        Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive ...
# 3                                                    U dun say so early hor... U c already then say...
# 4                                        Nah I don't think he goes to usf, he lives around here though
#
#                                                                                           Text_cleaned  \
# 0  [Go, jurong, point, crazy, Available, bugis, n, great, world, la, e, buffet, Cine, got, amore, wat]
# 1                                                                       [Ok, lar, Joking, wif, u, oni]
# 2  [Free, entry, 2, wkly, comp, win, FA, Cup, final, tkts, 21st, May, 2005, Text, FA, 87121, receiv...
# 3                                                        [U, dun, say, early, hor, U, c, already, say]
# 4                                              [Nah, I, dont, think, goes, usf, lives, around, though]
#
#                                                                                           Text_stemmed  \
# 0        [Go, jurong, point, crazi, avail, bugi, n, great, world, la, e, buffet, cine, got, amor, wat]
# 1                                                                         [Ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, FA, cup, final, tkt, 21st, may, 2005, text, FA, 87121, receiv,...
# 3                                                        [U, dun, say, earli, hor, U, c, alreadi, say]
# 4                                                [nah, I, dont, think, goe, usf, live, around, though]
#
#                                                                                        Text_lemmatized
# 0        [Go, jurong, point, crazi, avail, bugi, n, great, world, la, e, buffet, cine, got, amor, wat]
# 1                                                                         [Ok, lar, joke, wif, u, oni]
# 2  [free, entri, 2, wkli, comp, win, FA, cup, final, tkt, 21st, may, 2005, text, FA, 87121, receiv,...
# 3                                                        [U, dun, say, earli, hor, U, c, alreadi, say]
# 4                                                [nah, I, dont, think, goe, usf, live, around, though]

# %% [markdown]
# ### Change labels from ham to -1 and spam to 1

# %%
data.replace({'label': {'ham': -1, 'spam': 1}}, inplace=True)

# %%
#Checks label counts are still the same
data['label'].value_counts()
# Out:
# -1    4825
#  1     747
# Name: label, dtype: int64

# %%
data.label.head()
# Out:
# 0   -1
# 1   -1
# 2    1
# 3   -1
# 4   -1
# Name: label, dtype: int64

# %% [markdown]
# ### Extract predictor variables and target label

# %% [markdown]
# We run tests with the **Text_cleaned**, **Text_stemmed** and **Text_lemmatized**

# %%
Y = data.label.values.reshape(len(data),1)
X = data.Text_stemmed.values.reshape(len(Y),1)  #data.iloc[:,4].values.shape

# %%
X.shape
# Out:
# (5572, 1)

# %%
Y.shape
# Out:
# (5572, 1)

# %%
# Split data into Training, Test and Validation data sets
xtr, xva, xte, ytr, yva, yte = splitdata(X, Y, 7, 0.9)
# Out:
# 5015 training examples and 1 features
# 279 validation examples and 1 features
# 278 testing examples and 1 features

# %%
num_of_train_pos = ytr[ytr==1].sum()
num_of_val_pos   = yva[yva==1].sum()
num_of_test_pos  = yte[yte==1].sum()
num_of_train_neg = len(ytr) -  ytr[ytr==1].sum()
num_of_val_neg   = len(yva) -  yva[yva==1].sum()
num_of_test_neg  = len(yte) -  yte[yte==1].sum()

# %%
print("Training set has {} positive and {} negative labels".format(num_of_train_pos ,num_of_train_neg))
print("Validation set has {} positive and {} negative labels".format(num_of_val_pos,num_of_val_neg))
print("Test set has {} positive and {} negative labels".format(num_of_test_pos,num_of_test_neg))
# Out:
# Training set has 688 positive and 4327 negative labels
# Validation set has 31 positive and 248 negative labels
# Test set has 28 positive and 250 negative labels

# %%
# Initialize the plot
fig = plt.figure(figsize=(18,6))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

Train = [594, 3864]
Val   = [ 79,  478] 
Test  = [ 74,  483]

Labels = ['Spam', 'Ham']
Explode = [0,0.1]

ax1.pie(Train, explode=Explode, labels=Labels,shadow=True,startangle=45,autopct='%1.2f%%');
ax1.set_title('Train set label distribution',fontsize=20);

ax2.pie(Val, explode=Explode, labels=Labels ,shadow=True,startangle=45,autopct='%1.2f%%');
ax2.set_title('Validation set label distribution',fontsize=20);

ax3.pie(Test, explode=Explode, labels=Labels, shadow=True,startangle=45,autopct='%1.2f%%');
ax3.set_title('Test set label distribution',fontsize=20);

# %%
split_data = ['Training', 'Validation','Test']
pos_label  = [num_of_train_pos, num_of_val_pos, num_of_test_pos]
neg_label  = [num_of_train_neg, num_of_val_neg,num_of_test_neg]

index = np.arange(3)
width = 0.30

plt.bar(index,pos_label, width, color='maroon', label='Positive Label')
plt.bar(index+width,neg_label, width, color='grey', label='Negative Label')
plt.title("Labels")

plt.xlabel("Data")
plt.ylabel("Number of values")

plt.xticks(index+width/2, split_data)

plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Run Classifiers

# %%
#kernel = ['Geditdist','Geditdist_Levenshtein','Geditdist_norm_intersect','Geditdist_norm_max','Geditdist_norm']
kernel = ['Geditdist','Geditdist_norm']

# %%
#Set Kernel parameter
params = {}
params['Geditdist']                = [0.00000125,0.0000125,0.0001,0.0125,12.5,125]
params['Geditdist_Levenshtein']    = [0.00000125,0.0000125,0.0001,0.0125,12.5,125]
params['Geditdist_norm_intersect'] = [0.00000125,0.0000125,0.0001,0.0125,12.5,125]
params['Geditdist_norm_max']       = [0.00000125,0.0000125,0.0001,0.0125,12.5,125]
params['Geditdist_norm']           = [0.00000125,0.0000125,0.0001,0.0125,12.5,125]

# %%
Exp = fitkernelmodel(xtr, xte, ytr, yte, kernel, params)
# Out:
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.7228458498023715 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.8871428571428572 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.9238571428571429 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 10.0719% (28/278) (classification)
# --> The total of 278 predicted with only 28 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 28
# Actual label is False while we predicted True - False Positive 250
# Actual label is True while we predicted False - False Negative 0
# Actual label is False while we predicted False - True Negatve 0
#
# No Negative outcomes predicted
# Negative predicted value set to 0
# =============================================
# --> 278 positive outcomes predicted
# --> 0 negative outcomes predicted
# --> An accuracy of 10.07 % was achieved
# --> Sensitity of 1.0 was achieved
# --> Specificity of 0.0 was achieved
# --> 1.0 rate of positive prediction
# --> 0.0 rate of negative prediction
# --> 0.0 false negative rate was achieved
# --> 1.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0
# --> Recall value 0f 1.0 achieved
# --> The precision vaue of 0.1 achieved
# --> An Fscore of 0.18 achieved
# --> An AUC value of 0.17642857142857143 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 88.4918% (246/278) (classification)
# --> The total of 278 predicted with only 255 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 5
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 23
# Actual label is False while we predicted False - True Negatve 250
#
# --> 5 positive outcomes predicted
# --> 273 negative outcomes predicted
# --> An accuracy of 91.73 % was achieved
# --> Sensitity of 0.18 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.02 rate of positive prediction
# --> 0.98 rate of negative prediction
# --> 0.82 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.92
# --> Recall value 0f 0.18 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.31 achieved
# --> An AUC value of 1.0 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 88.4918% (246/278) (classification)
# --> The total of 278 predicted with only 255 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 5
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 23
# Actual label is False while we predicted False - True Negatve 250
#
# --> 5 positive outcomes predicted
# --> 273 negative outcomes predicted
# --> An accuracy of 91.73 % was achieved
# --> Sensitity of 0.18 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.02 rate of positive prediction
# --> 0.98 rate of negative prediction
# --> 0.82 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.92
# --> Recall value 0f 0.18 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.31 achieved
# --> An AUC value of 1.0 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.738095238095238 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.738095238095238 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.8495714285714286 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 22.4238% (62/278) (classification)
# --> The total of 278 predicted with only 69 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 27
# Actual label is False while we predicted True - False Positive 208
# Actual label is True while we predicted False - False Negative 1
# Actual label is False while we predicted False - True Negatve 42
#
# --> 235 positive outcomes predicted
# --> 43 negative outcomes predicted
# --> An accuracy of 24.82 % was achieved
# --> Sensitity of 0.96 was achieved
# --> Specificity of 0.17 was achieved
# --> 0.85 rate of positive prediction
# --> 0.15 rate of negative prediction
# --> 0.04 false negative rate was achieved
# --> 0.83 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.98
# --> Recall value 0f 0.96 achieved
# --> The precision vaue of 0.11 achieved
# --> An Fscore of 0.2 achieved
# --> An AUC value of 0.7195714285714285 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 86.481% (240/278) (classification)
# --> The total of 278 predicted with only 262 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 12
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 16
# Actual label is False while we predicted False - True Negatve 250
#
# --> 12 positive outcomes predicted
# --> 266 negative outcomes predicted
# --> An accuracy of 94.24 % was achieved
# --> Sensitity of 0.43 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.04 rate of positive prediction
# --> 0.96 rate of negative prediction
# --> 0.57 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.94
# --> Recall value 0f 0.43 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.6 achieved
# --> An AUC value of 1.0 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 88.4918% (246/278) (classification)
# --> The total of 278 predicted with only 255 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 5
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 23
# Actual label is False while we predicted False - True Negatve 250
#
# --> 5 positive outcomes predicted
# --> 273 negative outcomes predicted
# --> An accuracy of 91.73 % was achieved
# --> Sensitity of 0.18 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.02 rate of positive prediction
# --> 0.98 rate of negative prediction
# --> 0.82 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.92
# --> Recall value 0f 0.18 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.31 achieved
# --> An AUC value of 1.0 achieved

# %%
Perf, Analysisdf = Analyse_Results(Exp)
# Out:
#                   Pos  Neg   Accu   Sen  Spec   RPP   RNP  Miss  Fall   NPV  \
# Geditdist_0         0  278  89.93  0.00  1.00  0.00  1.00  1.00  0.00  0.90
# Geditdist_1         0  278  89.93  0.00  1.00  0.00  1.00  1.00  0.00  0.90
# Geditdist_2         0  278  89.93  0.00  1.00  0.00  1.00  1.00  0.00  0.90
# Geditdist_3       278    0  10.07  1.00  0.00  1.00  0.00  0.00  1.00  0.00
# Geditdist_4         5  273  91.73  0.18  1.00  0.02  0.98  0.82  0.00  0.92
# Geditdist_5         5  273  91.73  0.18  1.00  0.02  0.98  0.82  0.00  0.92
# Geditdist_norm_0    0  278  89.93  0.00  1.00  0.00  1.00  1.00  0.00  0.90
# Geditdist_norm_1    0  278  89.93  0.00  1.00  0.00  1.00  1.00  0.00  0.90
# Geditdist_norm_2    0  278  89.93  0.00  1.00  0.00  1.00  1.00  0.00  0.90
# Geditdist_norm_3  235   43  24.82  0.96  0.17  0.85  0.15  0.04  0.83  0.98
# Geditdist_norm_4   12  266  94.24  0.43  1.00  0.04  0.96  0.57  0.00  0.94
# Geditdist_norm_5    5  273  91.73  0.18  1.00  0.02  0.98  0.82  0.00  0.92
#
#                   Recall  Precision  Fscore
# Geditdist_0         0.00       0.00    0.00
# Geditdist_1         0.00       0.00    0.00
# Geditdist_2         0.00       0.00    0.00
# Geditdist_3         1.00       0.10    0.18
# Geditdist_4         0.18       1.00    0.31
# Geditdist_5         0.18       1.00    0.31
# Geditdist_norm_0    0.00       0.00    0.00
# Geditdist_norm_1    0.00       0.00    0.00
# Geditdist_norm_2    0.00       0.00    0.00
# Geditdist_norm_3    0.96       0.11    0.20
# Geditdist_norm_4    0.43       1.00    0.60
# Geditdist_norm_5    0.18       1.00    0.31
#                  train_kernel_time test_kernel_time diag_Dominance is_PSD  \
# Geditdist_0                5871.05          317.848          False   True
# Geditdist_1                5931.05          313.383          False   True
# Geditdist_2                5887.92          312.479          False   True
# Geditdist_3                6185.88          336.001          False   True
# Geditdist_4                6076.83          309.444          False  False
# Geditdist_5                6002.29          314.486          False  False
# Geditdist_norm_0           5951.74          316.009          False   True
# Geditdist_norm_1           5885.61          312.903          False   True
# Geditdist_norm_2           5890.57          312.686          False   True
# Geditdist_norm_3           5945.52          316.547          False   True
# Geditdist_norm_4           5976.49          318.048          False  False
# Geditdist_norm_5           5836.32          305.661          False  False
#
#                  num_Of_SV       AUC
# Geditdist_0              2  0.722846
# Geditdist_1             12  0.887143
# Geditdist_2             13  0.923857
# Geditdist_3             34  0.176429
# Geditdist_4           4649         1
# Geditdist_5           4649         1
# Geditdist_norm_0         2  0.738095
# Geditdist_norm_1         2  0.738095
# Geditdist_norm_2        11  0.849571
# Geditdist_norm_3        22  0.719571
# Geditdist_norm_4      4649         1
# Geditdist_norm_5      4649         1

# %%
plotResult(Perf)

# %%
#kernel = ['edist','edist_L','edist_n','edist_m','edist_i']
#kernel = ['Gedist','Gedist_L']
kernel = ['Geditdist_norm_intersect','Geditdist_norm_max']

# %%
#Set Kernel parameter
#params = {}
#params['Gedist']   = [0.0001,0.0125,12.5]
#params['Gedist_L'] = [0.0001,0.0125,12.5]
#params['edist_i'] = [1]
#params['edist_m'] = [1]
#params['edist_n'] = [1]

# %%
Exp2 = fitkernelmodel(xtr, xte, ytr, yte, kernel, params)
# Out:
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.45469705391884374 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.45469705391884374 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.47174265899365503 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 36.2119% (101/278) (classification)
# --> The total of 278 predicted with only 101 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 19
# Actual label is False while we predicted True - False Positive 168
# Actual label is True while we predicted False - False Negative 9
# Actual label is False while we predicted False - True Negatve 82
#
# --> 187 positive outcomes predicted
# --> 91 negative outcomes predicted
# --> An accuracy of 36.33 % was achieved
# --> Sensitity of 0.68 was achieved
# --> Specificity of 0.33 was achieved
# --> 0.67 rate of positive prediction
# --> 0.33 rate of negative prediction
# --> 0.32 false negative rate was achieved
# --> 0.67 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.68 achieved
# --> The precision vaue of 0.1 achieved
# --> An Fscore of 0.17 achieved
# --> An AUC value of 0.547144754316069 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 84.7575% (236/278) (classification)
# --> The total of 278 predicted with only 268 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 18
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 10
# Actual label is False while we predicted False - True Negatve 250
#
# --> 18 positive outcomes predicted
# --> 260 negative outcomes predicted
# --> An accuracy of 96.4 % was achieved
# --> Sensitity of 0.64 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.06 rate of positive prediction
# --> 0.94 rate of negative prediction
# --> 0.36 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.96
# --> Recall value 0f 0.64 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.78 achieved
# --> An AUC value of 0.9887057387057387 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 85.332% (237/278) (classification)
# --> The total of 278 predicted with only 266 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 16
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 12
# Actual label is False while we predicted False - True Negatve 250
#
# --> 16 positive outcomes predicted
# --> 262 negative outcomes predicted
# --> An accuracy of 95.68 % was achieved
# --> Sensitity of 0.57 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.06 rate of positive prediction
# --> 0.94 rate of negative prediction
# --> 0.43 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.95
# --> Recall value 0f 0.57 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.73 achieved
# --> An AUC value of 1.0 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.694296577946768 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.694296577946768 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.694296577946768 achieved
# The matrix is not diagonally dominant
# --> Kernel is valid and PSD
# Accuracy = 89.9281% (250/278) (classification)
# --> The total of 278 predicted with only 250 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 0
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 28
# Actual label is False while we predicted False - True Negatve 250
#
# No True positives or False positives predicted
# =============================================
# Fscore cannot be calculated as denominator is 0
# =============================================
# --> 0 positive outcomes predicted
# --> 278 negative outcomes predicted
# --> An accuracy of 89.93 % was achieved
# --> Sensitity of 0.0 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.0 rate of positive prediction
# --> 1.0 rate of negative prediction
# --> 1.0 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.9
# --> Recall value 0f 0.0 achieved
# --> The precision vaue of 0 achieved
# --> An Fscore of 0 achieved
# --> An AUC value of 0.9622857142857143 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 85.6193% (238/278) (classification)
# --> The total of 278 predicted with only 265 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 15
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 13
# Actual label is False while we predicted False - True Negatve 250
#
# --> 15 positive outcomes predicted
# --> 263 negative outcomes predicted
# --> An accuracy of 95.32 % was achieved
# --> Sensitity of 0.54 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.05 rate of positive prediction
# --> 0.95 rate of negative prediction
# --> 0.46 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.95
# --> Recall value 0f 0.54 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.7 achieved
# --> An AUC value of 0.6799999999999999 achieved
# The matrix is not diagonally dominant
# The matrix is diagonally dominant
# --> Kernel is not PSD
# Accuracy = 88.4918% (246/278) (classification)
# --> The total of 278 predicted with only 255 accurate predictions
#
# =======================
# Ground Truth comparison
# =======================
# Actual label is True while we predicted True - True Positive 5
# Actual label is False while we predicted True - False Positive 0
# Actual label is True while we predicted False - False Negative 23
# Actual label is False while we predicted False - True Negatve 250
#
# --> 5 positive outcomes predicted
# --> 273 negative outcomes predicted
# --> An accuracy of 91.73 % was achieved
# --> Sensitity of 0.18 was achieved
# --> Specificity of 1.0 was achieved
# --> 0.02 rate of positive prediction
# --> 0.98 rate of negative prediction
# --> 0.82 false negative rate was achieved
# --> 0.0 false positve rate (fallout) was achieved
# --> Negative predictive value of 0.92
# --> Recall value 0f 0.18 achieved
# --> The precision vaue of 1.0 achieved
# --> An Fscore of 0.31 achieved
# --> An AUC value of 1.0 achieved

# %%
Perf2, Analysisdf2 = Analyse_Results(Exp2)
# Out:
#                             Pos  Neg   Accu   Sen  Spec   RPP   RNP  Miss  \
# Geditdist_norm_intersect_0    0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_intersect_1    0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_intersect_2    0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_intersect_3  187   91  36.33  0.68  0.33  0.67  0.33  0.32
# Geditdist_norm_intersect_4   18  260  96.40  0.64  1.00  0.06  0.94  0.36
# Geditdist_norm_intersect_5   16  262  95.68  0.57  1.00  0.06  0.94  0.43
# Geditdist_norm_max_0          0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_max_1          0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_max_2          0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_max_3          0  278  89.93  0.00  1.00  0.00  1.00  1.00
# Geditdist_norm_max_4         15  263  95.32  0.54  1.00  0.05  0.95  0.46
# Geditdist_norm_max_5          5  273  91.73  0.18  1.00  0.02  0.98  0.82
#
#                             Fall   NPV  Recall  Precision  Fscore
# Geditdist_norm_intersect_0  0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_intersect_1  0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_intersect_2  0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_intersect_3  0.67  0.90    0.68        0.1    0.17
# Geditdist_norm_intersect_4  0.00  0.96    0.64        1.0    0.78
# Geditdist_norm_intersect_5  0.00  0.95    0.57        1.0    0.73
# Geditdist_norm_max_0        0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_max_1        0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_max_2        0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_max_3        0.00  0.90    0.00        0.0    0.00
# Geditdist_norm_max_4        0.00  0.95    0.54        1.0    0.70
# Geditdist_norm_max_5        0.00  0.92    0.18        1.0    0.31
#                            train_kernel_time test_kernel_time diag_Dominance  \
# Geditdist_norm_intersect_0           6432.93          377.211          False
# Geditdist_norm_intersect_1           6322.55          317.284          False
# Geditdist_norm_intersect_2            5993.9          317.715          False
# Geditdist_norm_intersect_3           5938.01          314.699          False
# Geditdist_norm_intersect_4           5899.78          314.324          False
# Geditdist_norm_intersect_5            6204.9          326.421          False
# Geditdist_norm_max_0                 6032.95          320.495          False
# Geditdist_norm_max_1                 5982.82          317.922          False
# Geditdist_norm_max_2                 6056.32          320.778          False
# Geditdist_norm_max_3                 5972.53          316.792          False
# Geditdist_norm_max_4                 6134.04          325.163          False
# Geditdist_norm_max_5                 5971.03          316.137          False
#
#                            is_PSD num_Of_SV       AUC
# Geditdist_norm_intersect_0   True         2  0.454697
# Geditdist_norm_intersect_1   True         2  0.454697
# Geditdist_norm_intersect_2   True         8  0.471743
# Geditdist_norm_intersect_3   True        10  0.547145
# Geditdist_norm_intersect_4  False      4508  0.988706
# Geditdist_norm_intersect_5  False      4565         1
# Geditdist_norm_max_0         True         2  0.694297
# Geditdist_norm_max_1         True         2  0.694297
# Geditdist_norm_max_2         True         2  0.694297
# Geditdist_norm_max_3         True        72  0.962286
# Geditdist_norm_max_4        False      4649      0.68
# Geditdist_norm_max_5        False      4649         1

# %%
plotResult(Perf2)
